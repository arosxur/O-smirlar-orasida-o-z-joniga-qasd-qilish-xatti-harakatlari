# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_excel("suicide.xlsx")
data.head(20)
# Out:
#                country  year age_group     sex  currently_drank_alcohol  \
# 0            Argentina  2018     13-15  Female                     50.3
# 1            Argentina  2018     13-15    Male                     44.9
# 2            Argentina  2018     16-17  Female                     67.2
# 3            Argentina  2018     16-17    Male                     68.1
# 4            Argentina  2012     13-15    Male                     49.3
# 5            Argentina  2012     13-15  Female                     50.7
# 6            Barabados  2011     13-15    Male                     29.4
# 7            Barabados  2011     13-15  Female                     26.6
# 8                Benin  2016     13-15    Male                     38.0
# 9                Benin  2016     13-15  Female                     42.4
# 10               Benin  2016     16-17    Male                     46.5
# 11               Benin  2016     16-17  Female                     36.1
# 12              Bhutan  2016     13-15    Male                     26.0
# 13              Bhutan  2016     13-15  Female                     11.7
# 14              Bhutan  2016     16-17    Male                     41.2
# 15              Bhutan  2016     16-17  Female                     21.4
# 16  Brunei Darussalam   2014     13-15    Male                      4.4
# 17  Brunei Darussalam   2014     13-15  Female                      3.2
# 18  Brunei Darussalam   2014     16-17    Male                      9.4
# 19  Brunei Darussalam   2014     16-17  Female                      2.1
#
#     really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 0               30.7        27.8            7.9                     41.5
# 1               26.1        39.1            8.4                     44.5
# 2               56.3        22.5           21.9                     37.1
# 3               55.8        27.9           27.0                     39.8
# 4               28.9        35.9           10.6                     46.2
# 5               26.8        21.8            6.5                     49.9
# 6               80.2        32.3           15.6                     48.1
# 7               78.0        39.1            7.4                     44.8
# 8               19.3        12.7            0.8                     35.7
# 9               16.8        18.3            0.2                     39.7
# 10              29.6         3.3            2.1                     33.3
# 11              20.0        14.7            0.6                     34.1
# 12              22.8         9.7           21.7                     38.7
# 13               9.3        15.7            3.6                     45.9
# 14              44.6         5.9           35.5                     41.0
# 15              20.9        13.2            7.4                     48.1
# 16               4.5        37.4            0.6                     31.4
# 17               2.3        34.8            0.0                     25.7
# 18               7.5        32.5            0.5                     30.8
# 19               2.4        33.6            1.0                     25.4
#
#      missed_classes_without_permission  smoke_cig_currently  had_fights  \
# 0                                 24.7                 16.8        17.2
# 1                                 27.9                 12.1        33.2
# 2                                 34.0                 28.5        15.1
# 3                                 39.4                 28.0        33.6
# 4                                 32.0                 17.0        44.2
# 5                                 29.4                 20.5        24.7
# 6                                 14.6                  NaN        42.7
# 7                                 11.7                  NaN        29.7
# 8                                 18.8                  5.1        32.1
# 9                                  6.5                  1.3        27.3
# 10                                17.3                  6.9        28.8
# 11                                20.6                  2.0        17.8
# 12                                28.4                 32.5        51.7
# 13                                19.3                  9.6        34.3
# 14                                31.6                 43.8        46.6
# 15                                20.6                 17.1        29.6
# 16                                38.5                 13.9        31.9
# 17                                35.5                  4.3        17.1
# 18                                39.6                 26.5        27.2
# 19                                36.6                  6.3        13.1
#
#     bullied  got_seriously_injured  no_close_friends   attempted_suicide
# 0       NaN                   27.5                4.8               19.9
# 1       NaN                   37.4                5.5               10.4
# 2       NaN                   30.1                6.3               17.4
# 3       NaN                   40.3                6.6               11.2
# 4      42.1                   24.8                6.1               12.9
# 5      25.2                   24.2                4.3               18.9
# 6      30.3                   49.1                6.8               10.4
# 7      31.1                   41.1                8.3               15.4
# 8      47.4                   48.4               10.8               14.4
# 9      51.5                   40.4               14.2                9.6
# 10     43.3                   51.0                9.7               13.4
# 11     39.8                   39.5               15.3               14.1
# 12     31.2                   50.8                7.8               10.9
# 13     28.9                   38.9               10.3               10.3
# 14     21.2                   46.7                6.9                9.7
# 15     23.2                   39.1                9.1               14.0
# 16     25.3                   37.1                2.7                4.5
# 17     21.7                   22.8                2.5                5.9
# 18     15.3                   38.9                4.9                4.5
# 19     14.8                   21.1                2.9                9.6

# %%
# number of rows and columns
data.shape
# Out:
# (106, 16)

# %%
davlatlar = data.sort_values(by=['country'],ascending=True)
davlatlar.tail(20)
# Out:
#                   country  year age_group     sex  currently_drank_alcohol  \
# 86           Timor-Leste   2015     16-17    Male                     27.2
# 87           Timor-Leste   2015     16-17  Female                     10.0
# 90   Trinidad and Tobago   2017     16-17    Male                     42.9
# 91   Trinidad and Tobago   2017     16-17  Female                     37.5
# 88   Trinidad and Tobago   2017     13-15    Male                     27.6
# 89   Trinidad and Tobago   2017     13-15  Female                     31.8
# 92                Tuvalu   2013     13-15    Male                     22.2
# 93                Tuvalu   2013     13-15  Female                      5.1
# 94               Uruguay   2012     13-15    Male                     47.2
# 95               Uruguay   2012     13-15  Female                     43.4
# 96               Vanuatu   2016     13-15    Male                     15.4
# 97               Vanuatu   2016     13-15  Female                      9.7
# 98               Vanuatu   2016     16-17    Male                     26.4
# 99               Vanuatu   2016     16-17  Female                     20.9
# 100              Vanuatu   2011     13-15    Male                     10.3
# 101              Vanuatu   2011     13-15  Female                      5.8
# 104    Wallis and Futuna   2015     16-17    Male                     48.3
# 102    Wallis and Futuna   2015     13-15    Male                     32.2
# 103    Wallis and Futuna   2015     13-15  Female                     24.4
# 105    Wallis and Futuna   2015     16-17  Female                     42.9
#
#      really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 86               21.5         3.9            5.8                     12.8
# 87                4.7         4.2            2.2                     13.7
# 90               41.3        27.2           27.6                     24.8
# 91               31.4        31.9            1.4                     28.1
# 88               23.1        32.9           13.9                     37.5
# 89               18.2        34.1            5.2                     32.4
# 92               22.5        44.3           11.3                     19.5
# 93                2.9        52.2            0.0                     19.6
# 94               24.5        29.7           11.6                     63.9
# 95               24.7        25.0            8.3                     61.0
# 96               15.1        12.8            5.3                     13.9
# 97                7.9        16.9            2.3                     17.4
# 98               25.7        11.2            9.8                     16.2
# 99               18.2        15.8            4.2                     21.5
# 100               8.9         8.9            5.0                     18.3
# 101               4.7        13.6            1.9                     20.2
# 104              53.7        57.8           10.1                     36.5
# 102              35.5        60.5            4.0                     36.3
# 103              27.1        63.0            2.0                     36.3
# 105              51.7        70.6            3.9                     37.8
#
#       missed_classes_without_permission  smoke_cig_currently  had_fights  \
# 86                                 44.0                 41.6        29.7
# 87                                 29.4                  7.1        19.7
# 90                                 33.4                 20.9        44.6
# 91                                 13.4                  9.7        17.9
# 88                                 20.5                 13.6        44.8
# 89                                 15.5                  7.5        22.9
# 92                                 35.4                 34.1        76.5
# 93                                 32.5                  8.4        65.8
# 94                                 22.3                  8.0        38.0
# 95                                 23.3                 12.6        15.4
# 96                                 59.7                 21.2        54.4
# 97                                 46.5                 13.3        28.1
# 98                                 62.2                 32.6        46.1
# 99                                 54.9                 24.6        31.3
# 100                                53.1                 19.4        59.9
# 101                                44.6                  8.2        41.8
# 104                                38.9                 40.0        49.6
# 102                                32.7                 25.7        48.7
# 103                                16.2                 29.9        22.9
# 105                                37.2                 41.7        17.3
#
#      bullied  got_seriously_injured  no_close_friends   attempted_suicide
# 86      29.7                  72.50                3.3                9.5
# 87      20.8                  65.70                5.2                7.8
# 90      15.5                  51.00               10.3               12.2
# 91      11.9                  42.60               11.1               17.5
# 88      13.2                  49.70               11.8               10.4
# 89      17.9                  36.40                6.5               17.9
# 92      40.1                  58.11               15.3               16.3
# 93      15.0                  35.60               14.9                3.6
# 94      17.7                  41.10                3.3                7.4
# 95      20.4                  26.20                2.1               10.8
# 96      60.0                  71.80                7.9               30.3
# 97      45.7                  51.20               10.7               18.6
# 98      48.0                  60.80                9.7               23.1
# 99      47.0                  51.50                7.6               16.7
# 100     68.0                  66.90               17.0               28.3
# 101     66.5                  57.40               14.3               19.5
# 104     23.6                  54.50                7.3                9.0
# 102     30.2                  51.20                4.1               14.7
# 103     30.9                  41.70                3.3               16.9
# 105     29.4                  30.40                1.5               16.2

# %%
total_rate = davlatlar['attempted_suicide']
total_rate.head(50)
# Out:
# 0     19.9
# 1     10.4
# 2     17.4
# 3     11.2
# 4     12.9
# 5     18.9
# 6     10.4
# 7     15.4
# 8     14.4
# 9      9.6
# 10    13.4
# 11    14.1
# 15    14.0
# 14     9.7
# 12    10.9
# 13    10.3
# 16     4.5
# 17     5.9
# 18     4.5
# 19     9.6
# 23    24.3
# 20    12.3
# 21    20.1
# 22    12.1
# 27    11.2
# 26    12.8
# 24    11.6
# 25     8.0
# 28     4.4
# 29     3.6
# 30     3.7
# 31     2.7
# 32    16.1
# 33    20.6
# 34    13.2
# 35    21.8
# 37    31.5
# 36    29.8
# 41     5.5
# 40     3.8
# 39     6.9
# 38     4.9
# 42     6.6
# 43     7.4
# 44     5.7
# 45     6.7
# 48     9.4
# 46    11.5
# 47    16.5
# 49    10.9
# Name: attempted_suicide, dtype: float64

# %%
ratio = davlatlar

jinsi = ratio['country']
jinsi

joniga_qasd_qilishi = ratio['attempted_suicide']
joniga_qasd_qilishi

plt.barh(jinsi, joniga_qasd_qilishi)
plt.show()

# %%
argentina = davlatlar.groupby(['country']).get_group('Argentina')
argentina
# Out:
#      country  year age_group     sex  currently_drank_alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
# 5  Argentina  2012     13-15  Female                     50.7
#
#    really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 0              30.7        27.8            7.9                     41.5
# 1              26.1        39.1            8.4                     44.5
# 2              56.3        22.5           21.9                     37.1
# 3              55.8        27.9           27.0                     39.8
# 4              28.9        35.9           10.6                     46.2
# 5              26.8        21.8            6.5                     49.9
#
#     missed_classes_without_permission  smoke_cig_currently  had_fights  \
# 0                                24.7                 16.8        17.2
# 1                                27.9                 12.1        33.2
# 2                                34.0                 28.5        15.1
# 3                                39.4                 28.0        33.6
# 4                                32.0                 17.0        44.2
# 5                                29.4                 20.5        24.7
#
#    bullied  got_seriously_injured  no_close_friends   attempted_suicide
# 0      NaN                   27.5                4.8               19.9
# 1      NaN                   37.4                5.5               10.4
# 2      NaN                   30.1                6.3               17.4
# 3      NaN                   40.3                6.6               11.2
# 4     42.1                   24.8                6.1               12.9
# 5     25.2                   24.2                4.3               18.9

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
labels = ['Really get drunk', 'Overweight', 'Use marijuana',  'Smoke cig currently', 'Got seriously injured', 'Had fights', 'Attempted suicide']
male = [49.3, 35.9, 10.6, 17.0, 24.8, 44.2, 12.9]
female = [50.7, 21.8, 6.5,20.5, 24.2, 24.7, 18.9]

x = np.arange(len(labels))  
width = 0.40  

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, male, width, label='Male')
rects2 = ax.bar(x + width/2, female, width, label='Female')

ax.set_ylabel('Percentage')
ax.set_title('Percentage by cases and gender in Argentina in 2012.')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
plt.xticks(rotation='vertical')

fig.tight_layout()

plt.show()

# %%
davlatlar = data.sort_values(by=['country'],ascending=True)
davlatlar
# Out:
#                 country  year age_group     sex  currently_drank_alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 0                30.7        27.8            7.9                     41.5
# 1                26.1        39.1            8.4                     44.5
# 2                56.3        22.5           21.9                     37.1
# 3                55.8        27.9           27.0                     39.8
# 4                28.9        35.9           10.6                     46.2
# ..                ...         ...            ...                      ...
# 101               4.7        13.6            1.9                     20.2
# 104              53.7        57.8           10.1                     36.5
# 102              35.5        60.5            4.0                     36.3
# 103              27.1        63.0            2.0                     36.3
# 105              51.7        70.6            3.9                     37.8
#
#       missed_classes_without_permission  smoke_cig_currently  had_fights  \
# 0                                  24.7                 16.8        17.2
# 1                                  27.9                 12.1        33.2
# 2                                  34.0                 28.5        15.1
# 3                                  39.4                 28.0        33.6
# 4                                  32.0                 17.0        44.2
# ..                                  ...                  ...         ...
# 101                                44.6                  8.2        41.8
# 104                                38.9                 40.0        49.6
# 102                                32.7                 25.7        48.7
# 103                                16.2                 29.9        22.9
# 105                                37.2                 41.7        17.3
#
#      bullied  got_seriously_injured  no_close_friends   attempted_suicide
# 0        NaN                   27.5                4.8               19.9
# 1        NaN                   37.4                5.5               10.4
# 2        NaN                   30.1                6.3               17.4
# 3        NaN                   40.3                6.6               11.2
# 4       42.1                   24.8                6.1               12.9
# ..       ...                    ...                ...                ...
# 101     66.5                   57.4               14.3               19.5
# 104     23.6                   54.5                7.3                9.0
# 102     30.2                   51.2                4.1               14.7
# 103     30.9                   41.7                3.3               16.9
# 105     29.4                   30.4                1.5               16.2
#
# [106 rows x 16 columns]

# %%
samoa = davlatlar.groupby(['country']).get_group('Samoa')
samoa
# Out:
#    country  year age_group     sex  currently_drank_alcohol  really_get_drunk  \
# 66   Samoa  2017     13-15    Male                     12.9               7.9
# 67   Samoa  2017     13-15  Female                      7.7               4.9
# 68   Samoa  2017     16-17    Male                     15.3              12.4
# 69   Samoa  2017     16-17  Female                     11.5               7.5
# 70   Samoa  2011     13-15    Male                     43.4              47.7
# 71   Samoa  2011     13-15  Female                     25.4              25.2
#
#     overweight  use_marijuana  have_understand_parents  \
# 66        53.6           12.0                     22.9
# 67        61.7            3.4                     27.3
# 68        50.6            9.6                     17.5
# 69        67.6            3.8                     31.0
# 70        43.4           43.2                     30.0
# 71        59.1           24.7                     36.7
#
#      missed_classes_without_permission  had_sexual_relation  \
# 66                                37.1                 32.9
# 67                                29.7                 13.6
# 68                                40.2                 42.4
# 69                                41.2                 16.8
# 70                                60.9                 68.5
# 71                                48.2                 44.9
#
#     smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 66                 10.2        56.4     43.0                   59.8
# 67                  6.4        39.6     33.9                   40.4
# 68                 17.4        56.7     35.6                   55.9
# 69                  9.5        34.1     32.5                   37.6
# 70                 42.2        73.3     78.6                   87.7
# 71                 25.3        62.1     69.4                   78.6
#
#     no_close_friends   attempted_suicide
# 66               13.4               24.0
# 67                7.9               20.7
# 68                7.1               19.7
# 69                7.6               21.0
# 70               17.4               67.2
# 71               14.9               53.7

# %%
kiribati = davlatlar.groupby(['country']).get_group('Kiribati')
kiribati
# Out:
#      country  year age_group     sex  currently_drank_alcohol  \
# 37  Kiribati  2011     13-15  Female                     19.3
# 36  Kiribati  2011     13-15    Male                     43.7
#
#     really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 37              10.4        46.4            1.6                     15.4
# 36              35.4        31.9            6.8                     14.8
#
#      missed_classes_without_permission  had_sexual_relation  \
# 37                                30.1                  9.8
# 36                                38.1                 37.2
#
#     smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 37                 19.5        28.5     32.2                   53.2
# 36                 34.3        43.3     42.1                   64.2
#
#     no_close_friends   attempted_suicide
# 37                2.1               31.5
# 36                3.1               29.8

# %%
indonesia = davlatlar.groupby(['country']).get_group('Indonesia')
indonesia
# Out:
#       country  year age_group     sex  currently_drank_alcohol  \
# 28  Indonesia  2015     13-15    Male                      6.1
# 29  Indonesia  2015     13-15  Female                      1.4
# 30  Indonesia  2015     16-17    Male                     12.1
# 31  Indonesia  2015     16-17  Female                      2.2
#
#     really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 28               5.1        15.7            2.1                     31.8
# 29               0.8        14.9            0.7                     36.2
# 30              12.7        12.6            2.9                     30.2
# 31               1.1        13.1            0.2                     38.8
#
#      missed_classes_without_permission  had_sexual_relation  \
# 28                                23.5                  6.9
# 29                                16.9                  4.0
# 30                                26.1                  7.4
# 31                                15.8                  2.5
#
#     smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 28                 21.5        35.9     23.7                   39.6
# 29                  1.5        13.1     19.0                   21.2
# 30                 33.0        23.5     24.0                   34.8
# 31                  1.5         7.0     13.0                   18.4
#
#     no_close_friends   attempted_suicide
# 28                3.8                4.4
# 29                2.4                3.6
# 30                4.0                3.7
# 31                1.6                2.7

# %%
laos = davlatlar.groupby(['country']).get_group('Laos')
laos
# Out:
#    country  year age_group     sex  currently_drank_alcohol  really_get_drunk  \
# 41    Laos  2015     16-17  Female                     35.7              23.2
# 40    Laos  2015     16-17    Male                     36.1              34.0
# 39    Laos  2015     13-15  Female                     20.8              10.9
# 38    Laos  2015     13-15    Male                     18.9              14.8
#
#     overweight  use_marijuana  have_understand_parents  \
# 41        11.0            0.3                     16.7
# 40        10.3            1.2                     15.5
# 39        11.8            0.1                     16.5
# 38        11.3            0.6                     18.5
#
#      missed_classes_without_permission  had_sexual_relation  \
# 41                                39.1                 10.7
# 40                                45.4                 24.7
# 39                                36.0                  6.9
# 38                                39.9                 12.5
#
#     smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 41                  1.2         3.5     12.0                   15.2
# 40                 12.1         6.4      9.9                   16.1
# 39                  1.6         8.7     11.3                   16.9
# 38                  5.7        12.0     15.2                   20.0
#
#     no_close_friends   attempted_suicide
# 41                3.5                5.5
# 40                5.5                3.8
# 39                3.5                6.9
# 38                7.0                4.9

# %%
malaysia = davlatlar.groupby(['country']).get_group('Malaysia')
malaysia
# Out:
#      country  year age_group     sex  currently_drank_alcohol  \
# 42  Malaysia  2012     13-15    Male                      9.3
# 43  Malaysia  2012     13-15  Female                      5.7
# 44  Malaysia  2012     16-17    Male                     13.6
# 45  Malaysia  2012     16-17  Female                      7.4
#
#     really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 42               6.8        25.3            1.4                     32.6
# 43               3.0        22.2            0.4                     32.3
# 44              11.0        11.9            1.5                     31.4
# 45               5.8        11.2            0.3                     29.6
#
#      missed_classes_without_permission  had_sexual_relation  \
# 42                                30.0                  9.5
# 43                                25.4                  6.9
# 44                                36.9                  9.7
# 45                                34.1                  7.5
#
#     smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 42                 17.1        38.5     24.0                   43.7
# 43                  1.9        21.9     17.8                   28.4
# 44                 27.0        29.1     12.9                   39.7
# 45                  2.5        16.4     12.0                   26.4
#
#     no_close_friends   attempted_suicide
# 42                3.6                6.6
# 43                2.8                7.4
# 44                3.2                5.7
# 45                2.7                6.7

# %%
namibia = davlatlar.groupby(['country']).get_group('Namibia')
namibia
# Out:
#     country  year age_group     sex  currently_drank_alcohol  \
# 56  Namibia  2013     13-15    Male                     26.4
# 57  Namibia  2013     13-15  Female                     21.4
# 58  Namibia  2013     16-17    Male                     42.2
# 59  Namibia  2013     16-17  Female                     34.9
#
#     really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 56              26.7         6.3            6.7                     40.2
# 57              16.9         8.4            3.9                     42.0
# 58              40.6         3.7           12.6                     38.2
# 59              26.6         8.3            4.9                     42.3
#
#      missed_classes_without_permission  had_sexual_relation  \
# 56                                23.7                 49.8
# 57                                23.4                 27.0
# 58                                28.9                 67.3
# 59                                24.7                 49.7
#
#     smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 56                 10.1        44.0     47.9                   65.9
# 57                  6.3        29.2     45.4                   53.2
# 58                 16.7        41.6     41.5                   58.5
# 59                  5.6        27.3     47.6                   50.0
#
#     no_close_friends   attempted_suicide
# 56               13.0               29.9
# 57               13.4               23.8
# 58               12.4               25.2
# 59               14.5               24.4

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["Samoa - 53.7",
          "Kiribati - 31.5",
          "Indonesia - 3.6",
          "Laos - 6.9 ",
          "Malaysia - 7.4 ",
          "Namibia - 23.8"]

data = [225, 150, 35, 50, 60, 100]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("13 - 15 yoshli qizlar orasidagi o`z joniga qasd qilish")

plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_excel("suicide.xlsx")
data.head()
# Out:
#      country  year age_group     sex  currently_drank_alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
#
#    really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 0              30.7        27.8            7.9                     41.5
# 1              26.1        39.1            8.4                     44.5
# 2              56.3        22.5           21.9                     37.1
# 3              55.8        27.9           27.0                     39.8
# 4              28.9        35.9           10.6                     46.2
#
#     missed_classes_without_permission  had_sexual_relation  \
# 0                                24.7                 25.7
# 1                                27.9                 38.4
# 2                                34.0                 59.1
# 3                                39.4                 68.6
# 4                                32.0                 43.5
#
#    smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 0                 16.8        17.2      NaN                   27.5
# 1                 12.1        33.2      NaN                   37.4
# 2                 28.5        15.1      NaN                   30.1
# 3                 28.0        33.6      NaN                   40.3
# 4                 17.0        44.2     42.1                   24.8
#
#    no_close_friends   attempted_suicide
# 0                4.8               19.9
# 1                5.5               10.4
# 2                6.3               17.4
# 3                6.6               11.2
# 4                6.1               12.9

# %%
p_name = data[['country', 'age_group', 'sex', 'really_get_drunk', 'use_marijuana', 'smoke_cig_currently', 'had_fights', 'got_seriously_injured', 'attempted_suicide' ]].nlargest(5,['attempted_suicide']).set_index('country')
p_name
# Out:
#          age_group     sex  really_get_drunk  use_marijuana  \
# country
# Samoa        13-15    Male              47.7           43.2
# Samoa        13-15  Female              25.2           24.7
# Kiribati     13-15  Female              10.4            1.6
# Vanuatu      13-15    Male              15.1            5.3
# Namibia      13-15    Male              26.7            6.7
#
#           smoke_cig_currently  had_fights  got_seriously_injured  \
# country
# Samoa                    42.2        73.3                   87.7
# Samoa                    25.3        62.1                   78.6
# Kiribati                 19.5        28.5                   53.2
# Vanuatu                  21.2        54.4                   71.8
# Namibia                  10.1        44.0                   65.9
#
#           attempted_suicide
# country
# Samoa                  67.2
# Samoa                  53.7
# Kiribati               31.5
# Vanuatu                30.3
# Namibia                29.9

# %%
category_names = ['Samoa - male', 'Samoa - female',
                  'Kiribati', 'Vanuatu', 'Namibia']
results = {
    'Really get drunk': [47.7, 25.2, 10.4, 15.1, 26.7],
    'Use marijuana': [43.2, 24.7, 1.6, 5.3, 6.7],
    'Smoke cig currently': [42.2, 25.3, 19.5, 21.2, 10.1],
    'Had fights': [73.3, 62.1, 28.5, 54.4, 44.0],
    'Got seriously injured': [87.7, 78.6, 53.2, 71.8, 65.9],
    'Attempted suicide': [67.2, 53.7, 31.5, 30.3, 29.9]
}


def survey(results, category_names):
   
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.colormaps['RdYlGn'](
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, label_type='center', color=text_color)
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='small')

    return fig, ax


survey(results, category_names)
plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_excel("suicide.xlsx")
data.head()
year = data.sort_values(by=['year'],ascending=True)
year
# Out:
#                  country  year age_group     sex  currently_drank_alcohol  \
# 65                  Peru  2010     13-15  Female                     26.0
# 54              Mongolia  2010     13-15    Male                      6.6
# 64                  Peru  2010     13-15    Male                     28.4
# 55              Mongolia  2010     13-15  Female                      4.5
# 71                 Samoa  2011     13-15  Female                     25.4
# ..                   ...   ...       ...     ...                      ...
# 88  Trinidad and Tobago   2017     13-15    Male                     27.6
# 3              Argentina  2018     16-17    Male                     68.1
# 2              Argentina  2018     16-17  Female                     67.2
# 1              Argentina  2018     13-15    Male                     44.9
# 0              Argentina  2018     13-15  Female                     50.3
#
#     really_get_drunk  overweight  use_marijuana  have_understand_parents  \
# 65              10.2        18.7            1.9                     38.4
# 54               6.6         6.2            2.9                     39.6
# 64              16.8        21.8            5.7                     33.5
# 55               3.9         8.1            0.7                     30.9
# 71              25.2        59.1           24.7                     36.7
# ..               ...         ...            ...                      ...
# 88              23.1        32.9           13.9                     37.5
# 3               55.8        27.9           27.0                     39.8
# 2               56.3        22.5           21.9                     37.1
# 1               26.1        39.1            8.4                     44.5
# 0               30.7        27.8            7.9                     41.5
#
#      missed_classes_without_permission  had_sexual_relation  \
# 65                                31.3                  9.6
# 54                                32.2                  9.9
# 64                                37.5                 24.3
# 55                                17.9                  4.5
# 71                                48.2                 44.9
# ..                                 ...                  ...
# 88                                20.5                 33.3
# 3                                 39.4                 68.6
# 2                                 34.0                 59.1
# 1                                 27.9                 38.4
# 0                                 24.7                 25.7
#
#     smoke_cig_currently  had_fights  bullied  got_seriously_injured  \
# 65                 11.9        21.5     48.2                   44.2
# 54                  9.2        63.3     36.7                   38.9
# 64                 22.9        52.4     46.7                   53.8
# 55                  2.0        18.6     19.8                   28.4
# 71                 25.3        62.1     69.4                   78.6
# ..                  ...         ...      ...                    ...
# 88                 13.6        44.8     13.2                   49.7
# 3                  28.0        33.6      NaN                   40.3
# 2                  28.5        15.1      NaN                   30.1
# 1                  12.1        33.2      NaN                   37.4
# 0                  16.8        17.2      NaN                   27.5
#
#     no_close_friends   attempted_suicide
# 65                5.3               22.0
# 54                4.4                7.2
# 64                5.7               12.0
# 55                4.5                9.4
# 71               14.9               53.7
# ..                ...                ...
# 88               11.8               10.4
# 3                 6.6               11.2
# 2                 6.3               17.4
# 1                 5.5               10.4
# 0                 4.8               19.9
#
# [106 rows x 17 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

year = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
population_by_continent = {
    '13 - 15': [22, 53.7, 18.9, 23.8, 5.9, 20.5, 20.1, 20.7, 19.9],
    '16 - 17': [0, 0, 6.7, 24.4, 9.6, 17.8, 27.3, 21.8, 17.4],
}

fig, ax = plt.subplots()
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys(), alpha=0.8)
ax.legend(loc='upper right')
ax.set_title('Attepted suicides')
ax.set_xlabel('Year')
ax.set_ylabel('Rate')

plt.show()
